# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
req = Request('https://in.investing.com/equities/itc-financial-summary?period_type=annually'
                , headers={'User-Agent': 'Mozilla/5.0'})

# %%
pages = urlopen(req).read()

# %%
soup = BeautifulSoup(pages.decode('utf-8'),'html.parser')

# %%
list_value = list(soup.children)

# %%
html_page = list_value[3]

# %%
html_body=list(html_page.children)[3]

# %%
html_body
# Out:
# <body>
# <div class="common-structure js-main-wrapper">
# <div class="js-global-elements">
# <div class="mask js-modal-wrapper hide">
# <div class="popup modal js-modal-content">
# <li class="button-tabs-item popup-wrapper">
# <div class="e-share-comp hide js-main-share-wrapper" tabindex="0">
# <div class="popup-header only-mobile">
# <h2 class="popup-header-title">share page</h2>
# <button aria-label="close this" class="button-icon close-button js-close-modal">
# <span aria-hidden="true" class="icon-close"></span>
# </button>
# </div>
# <header class="popup-header u-no-sep">
# <nav class="common-nav">
# <ul class="common-nav-list">
# <li class="common-nav-item">
# <button class="js-main-share-tabs-button common-link selected">
# <span class="text">Share</span>
# </button>
# </li>
# <li class="common-nav-item hide">
# <button class="js-main-share-tabs-button common-link">
# <span class="text">Embed</span>
# </button>
# </li>
# </ul>
# </nav>
# ...

# %%
html_body.findAllNext('h2',class_='section-title')[0].get_text().strip()
# Out:
# 'ITC Financial Summary'

# %%
dic = dict()
dic['Company'] = html_body.findAllNext('h2',class_='section-title')[0].get_text().strip()

# %%
 html_body.findAllNext('span', class_='text common-pre-text')[0].get_text()
# Out:
# 'For the nine months ended 31 December 2019, ITC Ltd revenues increased 6% to RS388.33B. Net income before extraordinary items increased 19% to RS107.69B. Revenues reflect Agri Business segment increase of 15% to RS85.55B, FMCG - Cigarettes segment increase of 6% to RS179.29B. Net income benefited from Other income increase of 30% to RS19.3B (income), Equity Earnings -Before Taxes increase of 1% to RS79.6M (income).'

# %%
dic['Summary'] =  html_body.findAllNext('span', class_='text common-pre-text')[0].get_text()

# %%
title_section= html_body.findAllNext('div', class_='section-title js-table-title-wrapper')

# %%
title_section[0].get_text().strip()
# Out:
# 'ITC Income Statement'

# %%
len(title_section)
# Out:
# 6

# %%
sections = html_body.findAllNext('section', class_='js-table-wrapper common-table-comp')

# %%
len(sections)
# Out:
# 7

# %%
sections[0].findAll('tr')
# Out:
# [<tr>
#  <th class="col-title" col-name="title">
#  <div class="th-wrapper">
#  <span class="text"></span>
#  </div>
#  </th>
#  <th class="col-1" col-name="1" data-type="numeric">
#  <div class="th-wrapper">
#  <span class="text">ITC</span>
#  </div>
#  </th>
#  </tr>, <tr class="common-table-item">
#  <td class="col-title">
#  <span class="text">Gross margin</span>
#  <span class="common-data-time">TTM</span>
#  </td></tr>]

# %%
sections[0].findParent().findNext('tbody').findAll('tr')
# Out:
# [<tr class="common-table-item">
#  <td class="col-title">
#  <span class="text">Gross margin</span>
#  <span class="common-data-time">TTM</span>
#  </td></tr>]

# %%
dir(html_body)
# Out:
# ['__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'descendants',
#  'encode',
#  'encode_contents',
# ...
